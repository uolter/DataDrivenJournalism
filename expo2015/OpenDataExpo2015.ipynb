# %% [markdown]
# # Aggiudicazioni delle gare per i lavori

# %%
import pandas as pd

CSV_DATASET = 'garelavoriaggiudicazioni.csv'

df = pd.read_csv(CSV_DATASET, sep=',')

# %%
df.head()
# Out:
#    Numero gara           RUP  \
# 0            1  Carlo Chiesa
# 1            2  Carlo Chiesa
# 2            2  Carlo Chiesa
# 3            2  Carlo Chiesa
# 4            2  Carlo Chiesa
#
#                                   Oggetto della gara  ID lotto         CIG  \
# 0  fornitura di edifici prefabbricati da adibirsi...        55  461919042C
# 1  realizzazione opere civili e impiantistiche di...        39  447635984C
# 2  realizzazione opere civili e impiantistiche di...        33  44763229C3
# 3  realizzazione opere civili e impiantistiche di...        34  4476386E92
# 4  realizzazione opere civili e impiantistiche di...        38  4476366E11
#
#      Cantiere                                  Oggetto del lotto  \
# 0  Campo Base  PROCEDURA APERTA PER L'AFFIDAMENTO IN APPALTO ...
# 1  Campo Base                                     URBANIZZAZIONI
# 2  Campo Base                                 SCAVI E RECINZIONI
# 3  Campo Base                                     PAVIMENTAZIONI
# 4  Campo Base                                         FONDAZIONI
#
#   Criterio di aggiudicazione Esito della procedura Tipo aggiudicatario  \
# 0    offerta più vantaggiosa           aggiudicata     impresa singola
# 1    offerta più vantaggiosa           aggiudicata     impresa singola
# 2           prezzo più basso           aggiudicata     impresa singola
# 3           prezzo più basso           aggiudicata                 ATI
# 4           prezzo più basso           aggiudicata                 ATI
#
#             ...            Importo componente lavori  \
# 0           ...                           5347188.06
# 1           ...                            635883.20
# 2           ...                            474254.44
# 3           ...                            637104.40
# 4           ...                            793613.83
#
#   Importo componente servizi Importo componente forniture  \
# 0                       0.00                         0.00
# 1                       0.00                         0.00
# 2                       0.00                         0.00
# 3                       0.00                         0.00
# 4                       0.00                         0.00
#
#   Importo totale attuazione sicurezza Somme non assoggettate a ribasso  \
# 0                           225436.45                             0.00
# 1                            50429.69                             0.00
# 2                            18727.24                             0.00
# 3                            14084.66                             0.00
# 4                            27777.58                             0.00
#
#   Importo progettazione Importo complessivo appalto  \
# 0                  0.00                  5572624.51
# 1                  0.00                   686312.89
# 2                  0.00                   492981.68
# 3                  0.00                   651189.06
# 4                  0.00                   821391.41
#
#   Importo totale somme a disposizione Importo complessivo intervento  \
# 0                                0.01                     5572624.52
# 1                          3310000.00                     3996312.89
# 2                          3310000.00                     3802981.68
# 3                          3310000.00                     3961189.06
# 4                          3310000.00                     4131391.41
#
#                      Stato
# 0         Collaudo sospeso
# 1        Collaudo Revocato
# 2  Collaudo Amministrativo
# 3                 Concluso
# 4                 Concluso
#
# [5 rows x 21 columns]

# %%
df.describe()
# Out:
#        Numero gara     ID lotto
# count    34.000000    34.000000
# mean    138.647059   268.147059
# std     277.440999   345.450969
# min       1.000000    33.000000
# 25%       6.250000    68.250000
# 50%      14.500000   127.500000
# 75%      22.750000   228.000000
# max     756.000000  1032.000000

# %%
aggiudicate = df[df['Esito della procedura'] == 'aggiudicata']

# %%
aggiudicate.describe()
# Out:
#        Numero gara     ID lotto
# count    29.000000    29.000000
# mean    160.137931   294.068966
# std     295.731988   368.591230
# min       1.000000    33.000000
# 25%       5.000000    59.000000
# 50%      15.000000   138.000000
# 75%      23.000000   246.000000
# max     756.000000  1032.000000

# %%
completati = df[df['Stato'] == 'Concluso']

# %%
completati.describe()
# Out:
#        Numero gara    ID lotto
# count     3.000000    3.000000
# mean      9.333333   66.333333
# std      12.701706   52.576928
# min       2.000000   34.000000
# 25%       2.000000   36.000000
# 50%       2.000000   38.000000
# 75%      13.000000   82.500000
# max      24.000000  127.000000
